# %% [markdown]
# # Introduction/Business Problem
#
# ## Inital phase
#
# In the innitial phase I will describe project's objective.
#
# The objective is to predic the severity of an accident given the weather and road conditions.
# Prediction will be done with the machine learning model by different supervised algorithms.
#
# Targeted audience are people interested in safety.

# %% [markdown]
# # Data
#
# ## Data understanding
#
# The label column used is SEVERITYDESC to predict if accident regarding Weather/Road condition will result in Injury or Property Damage Only.
#
# Data is extracted from csv file found on the Coursera Applied Data Science Capstone Week1.
#
# Data preparation will be done first to select the machine learning model with highest prediction accuracy.

# %%
import pandas as pd
import os

# %%
df = pd.read_csv(r"C:\Users\itrohar\Desktop\Applied Data Science Capstone Example Dataset\Data-Collisions.csv")
df.head(30)
# Out:
# C:\Users\itrohar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                          SEVERITYCODE           X          Y  \
# 0   2,-122.3231484,47.70314032,1,1307,1307,3502005...         NaN        NaN
# 1   1,-122.3472943,47.64717249,2,52200,52200,26079...         NaN        NaN
# 2   1,-122.33454,47.60787143,3,26700,26700,1482393...         NaN        NaN
# 3   1,-122.3348033,47.60480289,4,1144,1144,3503937...         NaN        NaN
# 4   2,-122.3064263,47.54573946,5,17700,17700,18074...         NaN        NaN
# 5   1,-122.3875981,47.69057545,6,320840,322340,E91...         NaN        NaN
# 6   1,-122.3384846,47.61853427,7,83300,83300,32825...         NaN        NaN
# 7                                                   2 -122.320780  47.614076
# ...

# %%
df.dtypes
# Out:
# SEVERITYCODE       object
# X                 float64
# Y                 float64
# OBJECTID          float64
# INCKEY            float64
# COLDETKEY         float64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC     float64
# SEVERITYCODE.1    float64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT       float64
# PEDCOUNT          float64
# PEDCYLCOUNT       float64
# VEHCOUNT          float64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE      float64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %%
df.iloc[7]['HITPARKEDCAR']

type(df.iloc[7]['HITPARKEDCAR'])
# Out:
# str

# %% [markdown]
# 'SEVERITYCODE''REPORTNO''STATUS''ADDRTYPE''LOCATION''EXCEPTRSNCODE''SEVERITYDESC''COLLISIONTYPE''INCDATE''INCDTTM'str
# 'JUNCTIONTYPE''SDOT_COLDESC''UNDERINFL''WEATHER''ROADCOND''LIGHTCOND''ST_COLCODE''ST_COLDESC''HITPARKEDCAR'
#
# 'X''Y''OBJECTID''INCKEY''COLDETKEY''INTKEY''EXCEPTRSNDESC''SEVERITYCODE.1''PERSONCOUNT''PEDCOUNT''PEDCYLCOUNT' numpy.float64
# 'VEHCOUNT''SDOT_COLCODE''SDOTCOLNUM''SEGLANEKEY''CROSSWALKKEY'
#
# 'INATTENTIONIND''PEDROWNOTGRNT''SPEEDING' float
#
# df[["SEVERITYCODE","REPORTNO","STATUS","ADDRTYPE","LOCATION","EXCEPTRSNCODE","SEVERITYDESC","COLLISIONTYPE","INCDATE","INCDTTM","JUNCTIONTYPE","SDOT_COLDESC","UNDERINFL","WEATHER","ROADCOND","LIGHTCOND","ST_COLCODE","ST_COLDESC","HITPARKEDCAR"]] = df[["SEVERITYCODE","REPORTNO","STATUS","ADDRTYPE","LOCATION","EXCEPTRSNCODE","SEVERITYDESC","COLLISIONTYPE","INCDATE","INCDTTM","JUNCTIONTYPE","SDOT_COLDESC","UNDERINFL","WEATHER","ROADCOND","LIGHTCOND","ST_COLCODE","ST_COLDESC","HITPARKEDCAR"]].astype("str")
# df[["X","Y","OBJECTID","INCKEY","COLDETKEY","INTKEY","EXCEPTRSNDESC","SEVERITYCODE.1","PERSONCOUNT","PEDCOUNT","PEDCYLCOUNT","VEHCOUNT","SDOT_COLCODE","SDOTCOLNUM","SEGLANEKEY","CROSSWALKKEY","INATTENTIONIND","PEDROWNOTGRNT","SPEEDING"]] = df[["X","Y","OBJECTID","INCKEY","COLDETKEY","INTKEY","EXCEPTRSNDESC","SEVERITYCODE.1","PERSONCOUNT","PEDCOUNT","PEDCYLCOUNT","VEHCOUNT","SDOT_COLCODE","SDOTCOLNUM","SEGLANEKEY","CROSSWALKKEY","INATTENTIONIND","PEDROWNOTGRNT","SPEEDING"]].astype("float")

# %%
df[['SEVERITYCODE']] = df[['SEVERITYCODE']].astype('str')

# %%
df.dtypes
# Out:
# SEVERITYCODE       object
# X                 float64
# Y                 float64
# OBJECTID          float64
# INCKEY            float64
# COLDETKEY         float64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC     float64
# SEVERITYCODE.1    float64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT       float64
# PEDCOUNT          float64
# PEDCYLCOUNT       float64
# VEHCOUNT          float64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE      float64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %%
# Identify and handle missing Values
import numpy as np
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    SEVERITYCODE     X     Y  OBJECTID  INCKEY  COLDETKEY  REPORTNO  STATUS  \
# 0         False  True  True      True    True       True      True    True
# 1         False  True  True      True    True       True      True    True
# 2         False  True  True      True    True       True      True    True
# 3         False  True  True      True    True       True      True    True
# 4         False  True  True      True    True       True      True    True
#
#    ADDRTYPE  INTKEY  ...  ROADCOND  LIGHTCOND  PEDROWNOTGRNT  SDOTCOLNUM  \
# 0      True    True  ...      True       True           True        True
# 1      True    True  ...      True       True           True        True
# 2      True    True  ...      True       True           True        True
# 3      True    True  ...      True       True           True        True
# 4      True    True  ...      True       True           True        True
#
#    SPEEDING  ST_COLCODE  ST_COLDESC  SEGLANEKEY  CROSSWALKKEY  HITPARKEDCAR
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# SEVERITYCODE
# False    194673
# Name: SEVERITYCODE, dtype: int64
#
# X
# True     167986
# False     26687
# Name: X, dtype: int64
#
# Y
# True     167986
# False     26687
# Name: Y, dtype: int64
#
# OBJECTID
# True     166427
# False     28246
# Name: OBJECTID, dtype: int64
#
# INCKEY
# True     166427
# False     28246
# Name: INCKEY, dtype: int64
#
# COLDETKEY
# True     166427
# False     28246
# Name: COLDETKEY, dtype: int64
#
# REPORTNO
# True     166427
# False     28246
# Name: REPORTNO, dtype: int64
#
# STATUS
# True     166427
# False     28246
# Name: STATUS, dtype: int64
#
# ADDRTYPE
# True     166430
# False     28243
# Name: ADDRTYPE, dtype: int64
#
# INTKEY
# True     186042
# False      8631
# Name: INTKEY, dtype: int64
#
# LOCATION
# True     167090
# False     27583
# Name: LOCATION, dtype: int64
#
# EXCEPTRSNCODE
# True     181210
# False     13463
# Name: EXCEPTRSNCODE, dtype: int64
#
# EXCEPTRSNDESC
# True    194673
# Name: EXCEPTRSNDESC, dtype: int64
#
# ...

# %%
#To see which values are present in a particular column, we can use the ".value_counts()" method
df['SEVERITYCODE'].value_counts()
# Out:
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                         16617
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                         11629
# ...

# %%
df['SEVERITYDESC'].value_counts()
# Out:
# Property Damage Only Collision    16617
# Injury Collision                  11629
# Name: SEVERITYDESC, dtype: int64

# %%
df['COLLISIONTYPE'].value_counts()
# Out:
# Other         14180
# Pedestrian     6393
# Parked Car     4575
# Cycles         1900
# Sideswipe       223
# Angles          211
# Rear Ended      191
# Head On          51
# Left Turn        46
# Right Turn       19
# Name: COLLISIONTYPE, dtype: int64

# %%
df['PERSONCOUNT'].value_counts()
# Out:
# 2.0     13443
# 1.0     11057
# 3.0      2049
# 0.0       706
# 4.0       636
# 5.0       197
# 6.0        79
# 7.0        30
# 8.0        21
# 11.0        8
# 10.0        5
# 9.0         4
# 12.0        4
# 15.0        1
# 81.0        1
# 22.0        1
# 17.0        1
# 32.0        1
# 30.0        1
# 19.0        1
# Name: PERSONCOUNT, dtype: int64

# %%
df['PEDCOUNT'].value_counts()
# Out:
# 0.0    21702
# 1.0     6315
# 2.0      204
# 3.0       19
# 4.0        4
# 5.0        1
# 6.0        1
# Name: PEDCOUNT, dtype: int64

# %%
df['PEDCYLCOUNT'].value_counts()
# Out:
# 0.0    26324
# 1.0     1896
# 2.0       26
# Name: PEDCYLCOUNT, dtype: int64

# %%
df['VEHCOUNT'].value_counts()
# Out:
# 1.0     21298
# 2.0      5844
# 0.0       627
# 3.0       357
# 4.0        74
# 5.0        21
# 6.0        11
# 7.0         6
# 8.0         4
# 11.0        1
# 12.0        1
# 9.0         1
# 10.0        1
# Name: VEHCOUNT, dtype: int64

# %%
df['WEATHER'].value_counts()
# Out:
# Clear                       14424
# Raining                      5720
# Overcast                     4001
# Unknown                      3117
# Snowing                       180
# Fog/Smog/Smoke                123
# Other                         119
# Sleet/Hail/Freezing Rain       31
# Blowing Sand/Dirt               7
# Severe Crosswind                6
# Partly Cloudy                   1
# Name: WEATHER, dtype: int64

# %%
df['ROADCOND'].value_counts()
# Out:
# Dry               15887
# Wet                8008
# Unknown            3120
# Ice                 375
# Snow/Slush          210
# Standing Water       52
# Other                46
# Sand/Mud/Dirt        38
# Oil                  33
# Name: ROADCOND, dtype: int64

# %%
df['LIGHTCOND'].value_counts()
# Out:
# Daylight                    13004
# Dark - Street Lights On      9964
# Unknown                      2781
# Dusk                          730
# Dawn                          536
# Dark - No Street Lights       401
# Dark - Street Lights Off      268
# Other                          59
# Dark - Unknown Lighting         5
# Name: LIGHTCOND, dtype: int64

# %%
df['SPEEDING'].value_counts()
# Out:
# Y    3622
# Name: SPEEDING, dtype: int64

# %%
df['HITPARKEDCAR'].value_counts()
# Out:
# N    27364
# Y      882
# Name: HITPARKEDCAR, dtype: int64
